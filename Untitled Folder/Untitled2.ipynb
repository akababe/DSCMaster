# %%
##Importing pyodbc module
import pandas as  pd
import pyodbc as odbc
import numpy as np

##connecting to your database through ODBC
cnxn = odbc.connect('DSN=195-serv;UID=support;PWD=support', autocommit=True)
cursor = cnxn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-10e9d9ef4ddd> in <module>
#       5
#       6 ##connecting to your database through ODBC
# ----> 7 cnxn = odbc.connect('DSN=195-serv;UID=support;PWD=support', autocommit=True)
#       8 cursor = cnxn.cursor()
#
# OperationalError: ('08001', '[08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]SQL Server does not exist or access denied. (17) (SQLDriverConnect); [08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionOpen (Connect()). (53)')

# %%
t = '1400 [tgljam],[noip],[noseq],[cntpr],[cntprset],[cntprall],[cntprsetall]'
te = 1400
dum = 0

check20144 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.201' and noseq = '44' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20144

check20145 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.201' and noseq = '45' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20145

check20146 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.201' and noseq = '46' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20146

check20271 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.202' and noseq = '71' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20271

check20272 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.202' and noseq = '72' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20272

check20273 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.202' and noseq = '73' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20273

check20027 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.200' and noseq = '27' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20027

check20028 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.200' and noseq = '28' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check20028


check19910 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.199' and noseq = '10' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check19910

check19911 =  pd.read_sql("Select top "+t+" from count_bs "
                    "where noip = '172.20.35.199' and noseq = '11' "
                     #"and tgljam >= '2021-04-29 09:30:00.000' "
                    "order by tgljam desc"
                   , cnxn )
check19911

i = 0 
dum9718= dum9719= dum9720= dum9721= dum981= dum982= dum989= dum9810= 0
dum9821= dum9822= dum9823= dum9824= dum9825= dum9826= dum9827= dum9828= 0
dum995= dum996= dum997= dum998= dum999= dum9910= dum9911= dum9912= 0

for i in range (te):
    if i < (te-1):
        
        cal9718 = check20144.cntpr[i] + check20144.cntprall [i+1] - check20144.cntprall [i]
        total9718 = cal9718 + dum9718
        dum9718 = total9718
        
        cal9719 = check20145.cntpr[i] + check20145.cntprall [i+1] - check20145.cntprall [i]
        total9719 = cal9719 + dum9719
        dum9719 = total9719
        
        cal9720 = check20146.cntpr[i] + check20146.cntprall [i+1] - check20146.cntprall [i]
        total9720 = cal9720 + dum9720
        dum9720 = total9720
        
        cal9721 = check20271.cntpr[i] + check20271.cntprall [i+1] - check20271.cntprall [i]
        total9721 = cal9721 + dum9721
        dum9721 = total9721
        
        cal981 = check20272.cntpr[i] + check20272.cntprall [i+1] - check20272.cntprall [i]
        total981 = cal981 + dum981
        dum981 = total981
        
        cal982 = check20273.cntpr[i] + check20273.cntprall [i+1] - check20273.cntprall [i]
        total982 = cal982 + dum982
        dum982 = total982
        
        cal989 = check20027.cntpr[i] + check20027.cntprall [i+1] - check20027.cntprall [i]
        total989 = cal989 + dum989
        dum989 = total989
        
        cal9810 = check20028.cntpr[i] + check20028.cntprall [i+1] - check20028.cntprall [i]
        total9810 = cal9810 + dum9810
        dum9810 = total9810
        
        cal9821 = check19910.cntpr[i] + check19910.cntprall [i+1] - check19910.cntprall [i]
        total9821 = cal9821 + dum9821
        dum9821 = total9821
        
        cal9822 = check19911.cntpr[i] + check19911.cntprall [i+1] - check19911.cntprall [i]
        total9822 = cal9822 + dum9822
        dum9822 = total9822

d = {'Area': [  '9718', '9719', '9720', '9721', '981' , '982'  , '989'  , '9810',
                '9821', '9822', 
               
             ], 
     'Diff': [total9718, total9719, total9720, total9721, total981 , total982, total989, total9810,
              total9821, total9822,
             ]}
df = pd.DataFrame(data=d)
df

# %%
flaw = check20271

bad_list = []
for i in range (te):
    if i < (te-1):
        calcu = flaw.cntpr[i] + flaw.cntprall [i+1] - flaw.cntprall [i]
        bad_list.append (calcu)        
        blist_frame = pd.DataFrame(data=bad_list)
flaw['different'] = blist_frame
show_result = flaw[((flaw['different'])<0) | ((flaw['different'])>0)]
show_result

# %%
check20271[655:666]
