# %%
##Importing pyodbc module
import pandas as  pd
import pyodbc as odbc
 
##connecting to your database through ODBC
cnxn = odbc.connect('DSN=250-serv;UID=sa;PWD=pass1234', autocommit=True)
cursor = cnxn.cursor()
 
##Executing a simple query and printing the records
#cursor.execute("SELECT (no_ip),(no_seq),(week_no),(no_incident),(cntr),(insert_date),(reason_down) FROM t_downtime ORDER BY no_incident desc")
#tables = cursor.fetchall()

#for row in tables:
#    print row.no_ip


#2019-02-15 10:44:17.617
#10:59:23.690
linev = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-14 16:28:05.340' and '2019-02-14 16:40:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
Bismillah = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-15  10:39:05.763' and '2019-02-15 13:22:23.630' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
aka = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-15  10:39:05.763' and '2019-02-15 10:57:23.510' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
s2 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-16  6:00:00.000' and '2019-02-16 15:49:05.983' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

senin_s1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-18  06:00:00.000' and '2019-02-18 13:30:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

senin_s2 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-18  13:31:05.817' and '2019-02-18 21:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

senin_s3 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-18  21:00:00.000' and '2019-02-19 05:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

selasa_s1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-19  06:00:00.000' and '2019-02-19 13:30:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

selasa_s2 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-19  16:11:05.943' and '2019-02-19 21:00:00.900' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

selasa_s3 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-19  21:00:00.000' and '2019-02-20 05:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

senin_css1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-18  06:00:00.000' and '2019-02-18 06:33:17.510' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)

sum_cntr_V = linev.cntr.sum()
batch_max_V =  max(linev.nobatch)

sum_cntr_Bismillah = Bismillah.cntr.sum()
batch_max_Bismillah =  max(Bismillah.nobatch)

sum_cntr_aka = aka.cntr.sum()
batch_max_aka =  max(aka.nobatch)

sum_cntr_s2 = s2.cntr.sum()
batch_max_s2 =  max(s2.nobatch)

sum_cntr_ss1 = senin_s1.cntr.sum()
batch_max_ss1 =  max(senin_s1.nobatch)

sum_cntr_ss2 = senin_s2.cntr.sum()
batch_max_ss2 =  max(senin_s2.nobatch)

sum_cntr_css1 = senin_css1.cntr.sum()
batch_max_css1 =  max(senin_css1.nobatch)

sum_cntr_ss3 = senin_s3.cntr.sum()
batch_max_ss3 =  max(senin_s3.nobatch)

##---------------------------------------
sum_cntr_sels1 = selasa_s1.cntr.sum()
batch_max_sels1 =  max(selasa_s1.nobatch)

sum_cntr_sels2 = selasa_s2.cntr.sum()
batch_max_sels2 =  max(selasa_s2.nobatch)
batch_min_sels2 =  min(selasa_s2.nobatch)


sum_cntr_sels3 = selasa_s3.cntr.sum()
batch_max_sels3 =  max(selasa_s3.nobatch)

a = sum_cntr_Bismillah - batch_max_Bismillah
b = sum_cntr_V - batch_max_V
c = sum_cntr_aka - batch_max_aka
d = sum_cntr_s2 - batch_max_s2
ss1 = sum_cntr_ss1 - batch_max_ss1
ss2 = sum_cntr_ss2 - batch_max_ss2
ss3 = sum_cntr_ss3 - batch_max_ss3
sels1 = sum_cntr_sels1 - batch_max_sels1
sels2 = sum_cntr_sels2 - (batch_max_sels2 - batch_min_sels2)
sels3 = sum_cntr_sels3 - batch_max_sels3
sels3
# Out:
# -1351

# %%
selasa_s3
# Out:
#     namamesin                  tgljam         barcode  cntr  nobatch
# 0      Conv-V 2019-02-20 04:59:17.723  18998866607367     6     4263
# 1      Conv-V 2019-02-20 04:59:11.640  18998866604953     3     4263
# 2      Conv-V 2019-02-20 04:59:05.340  18998866610237     4     4263
# 3      Conv-V 2019-02-20 04:58:17.540  18998866607367     2     4249
# 4      Conv-V 2019-02-20 04:58:11.473  18998866604953     2     4249
= pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-21 21:00:00.000' and '2019-02-22 05:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
jum_s1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-22 05:00:00.000' and '2019-02-22 13:30:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
jum_s2 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-22 13:30:00.000' and '2019-02-22 21:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
jum_s3 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-22 21:00:00.000' and '2019-02-23 05:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)



sum_cntr_rb1 = rabu_s1.cntr.sum()
batch_max_rb1 =  max(rabu_s1.nobatch)
rab1 = sum_cntr_rb1 - batch_max_rb1
#___---------------------------------
sum_cntr_rb2 = rabu_s2.cntr.sum()
batch_max_rb2 =  max(rabu_s2.nobatch)
rab2 = sum_cntr_rb2- batch_max_rb2
#------------------------------------
sum_cntr_km2 = kamis_s2.cntr.sum()
batch_max_km2 =  max(kamis_s2.nobatch)
kam2 = sum_cntr_km2- batch_max_km2
kam2
#------------------------------------
sum_cntr_km1 = kamis_s1.cntr.sum()
batch_max_km1 =  max(kamis_s1.nobatch)
kam1 = sum_cntr_km1- batch_max_km1
kam2
#------------------------------------
sum_cntr_km3 = kamis_s3.cntr.sum()
batch_max_km3 =  max(kamis_s3.nobatch)
kam3 = sum_cntr_km3- batch_max_km3
kam3
#------------------------------------
sum_cntr_jum1 = jum_s1.cntr.sum()
batch_max_jum1 =  max(jum_s1.nobatch)
jum1 = sum_cntr_jum1- batch_max_jum1
jum1
#------------------------------------
sum_cntr_jum2 = jum_s2.cntr.sum()
batch_max_jum2 =  max(jum_s2.nobatch)
jum2 = sum_cntr_jum2- batch_max_jum2
jum2
#------------------------------------
sum_cntr_jum3 = jum_s3.cntr.sum()
batch_max_jum3 =  max(jum_s3.nobatch)
jum3 = sum_cntr_jum3- batch_max_jum3
jum3
#------------------------------------
jum3
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1377             else:
# -> 1378                 cur.execute(*args)
#    1379             return cur
#
# Error: ('01000', '[01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionWrite (send()). (10054) (SQLExecDirectW); [01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]General network error. Check your network documentation. (11)')
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-60-3d94257b1cd0> in <module>
#      20
#      21 rabu_s1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-20  05:00:00.000' and '2019-02-20 13:30:000' and namamesin = 'Conv-V' "
# ...

# %%
jum_s3

# %%
jum_s3.groupby(['barcode'])['cntr'].describe()

# %%
##Importing pyodbc module
import pandas as  pd
import pyodbc as odbc
 
##connecting to your database through ODBC
cnxn = odbc.connect('DSN=250-serv;UID=sa;PWD=pass1234', autocommit=True)
cursor = cnxn.cursor()
 
##Executing a simple query and printing the records
#cursor.execute("SELECT (no_ip),(no_seq),(week_no),(no_incident),(cntr),(insert_date),(reason_down) FROM t_downtime ORDER BY no_incident desc")
#tables = cursor.fetchall()

#for row in tables:
#    print row.no_ip


#2019-02-15 10:44:17.617
#10:59:23.690

jumat_q1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-22  05:00:00.000' and '2019-02-22 13:30:000' and namamesin = 'Conv-Q' "
                    "order by tgljam desc",cnxn)
jumat_q1

# %%
##Importing pyodbc module
import pandas as  pd
import pyodbc as odbc
 
##connecting to your database through ODBC
cnxn = odbc.connect('DSN=250-serv;UID=sa;PWD=pass1234', autocommit=True)
cursor = cnxn.cursor()
 
##Executing a simple query and printing the records
#cursor.execute("SELECT (no_ip),(no_seq),(week_no),(no_incident),(cntr),(insert_date),(reason_down) FROM t_downtime ORDER BY no_incident desc")
#tables = cursor.fetchall()

#for row in tables:
#    print row.no_ip


#2019-02-15 10:44:17.617
#10:59:23.690

senin_se1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-27  05:00:00.000' and '2019-02-27 13:30:000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = senin_se1.cntr.sum()
batch_max_sen =  max(senin_se1.nobatch)
sen1 = sum_cnt_sen - batch_max_sen
sen1

# %%
##Importing pyodbc module
import pandas as  pd
import pyodbc as odbc
 
    
##connecting to your database through ODBC
cnxn = odbc.connect('DSN=250-serv;UID=sa;PWD=pass1234', autocommit=True)
cursor = cnxn.cursor()
 
##Executing a simple query and printing the records
#cursor.execute("SELECT (no_ip),(no_seq),(week_no),(no_incident),(cntr),(insert_date),(reason_down) FROM t_downtime ORDER BY no_incident desc")
#tables = cursor.fetchall()

#for row in tables:
#    print row.no_ip


#2019-02-15 10:44:17.617
#10:59:23.690

senin_se1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-28  16:14:04.747' and '2019-02-28 21:00:000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = senin_se1.cntr.sum()
batch_max_sen =  max(senin_se1.nobatch)
sen1 = sum_cnt_sen - batch_max_sen
senin_se1.head()

senin_se2 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-02-28  21:00:00.000' and '2019-03-01 05:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = senin_se2.cntr.sum()
batch_max_sen =  max(senin_se2.nobatch)
sen2 = sum_cnt_sen - batch_max_sen
senin_se2.head()

senin_se3 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-03-01  13:42:05.330' and '2019-03-01 20:30:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = senin_se3.cntr.sum()
batch_max_sen =  max(senin_se3.nobatch)
sen3 = sum_cnt_sen - batch_max_sen
sen3

# %%
senin_se3

# %%
senin_se3.groupby(['barcode'])['cntr'].describe()

# %%
##Importing pyodbc module
import pandas as  pd
import pyodbc as odbc
 
    
##connecting to your database through ODBC
cnxn = odbc.connect('DSN=250-serv;UID=sa;PWD=pass1234', autocommit=True)
cursor = cnxn.cursor()
 
##Executing a simple query and printing the records
#cursor.execute("SELECT (no_ip),(no_seq),(week_no),(no_incident),(cntr),(insert_date),(reason_down) FROM t_downtime ORDER BY no_incident desc")
#tables = cursor.fetchall()

#for row in tables:
#    print row.no_ip


#2019-02-15 10:44:17.617
#10:59:23.69

mon1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-03-04  13:30:00.000' and '2019-03-04 15:10:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = mon1.cntr.sum()
batch_max_sen =  max(mon1.nobatch)
mon11 = sum_cnt_sen - batch_max_sen

########################################################
sabtu1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-03-02  05:00:00.000' and '2019-03-02 13:30:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = sabtu1.cntr.sum()
batch_max_sen =  max(sabtu1.nobatch)
sabtu = sum_cnt_sen - batch_max_sen
mon11

# %%
sabtu1

# %%
mon1

# %%
##Importing pyodbc module
import pandas as  pd
import pyodbc as odbc
 
    
##connecting to your database through ODBC
cnxn = odbc.connect('DSN=250-serv;UID=sa;PWD=pass1234', autocommit=True)
cursor = cnxn.cursor()
 
##Executing a simple query and printing the records
#cursor.execute("SELECT (no_ip),(no_seq),(week_no),(no_incident),(cntr),(insert_date),(reason_down) FROM t_downtime ORDER BY no_incident desc")
#tables = cursor.fetchall()

#for row in tables:
#    print row.no_ip


#2019-02-15 10:44:17.617
#10:59:23.69

mon1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-03-04  13:30:00.000' and '2019-03-04 15:10:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = mon1.cntr.sum()
batch_max_sen =  max(mon1.nobatch)
mon11 = sum_cnt_sen - batch_max_sen

########################################################
sabtu1 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-03-02  05:00:00.000' and '2019-03-02 13:30:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = sabtu1.cntr.sum()
batch_max_sen =  max(sabtu1.nobatch)

########################################################
selasa = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-03-05  05:00:00.000' and '2019-03-05 10:00:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = selasa.cntr.sum()
batch_max_sen =  max(selasa.nobatch)
batch_min_sen =  min(selasa.nobatch)
selasa1 = sum_cnt_sen - (batch_max_sen-batch_min_sen)
########################################################
selasa2 = pd.read_sql("SELECT *  FROM mlog_test where tgljam between '2019-03-05  13:30:00.000' and '2019-03-05 15:06:00.000' and namamesin = 'Conv-V' "
                    "order by tgljam desc",cnxn)
sum_cnt_sen = selasa2.cntr.sum()
batch_max_sen =  max(selasa2.nobatch)
batch_min_sen =  min(selasa2.nobatch)
selasa2x = sum_cnt_sen - batch_max_sen
selasa2x
# Out:
# 0

# %%
selasa2
# Out:
#     namamesin                  tgljam         barcode  cntr  nobatch
# 0      Conv-V 2019-03-05 15:05:41.377         No Read     1     1013
# 1      Conv-V 2019-03-05 15:05:23.370  18998866610237     3     1013
# 2      Conv-V 2019-03-05 15:05:17.357  18998866604953     3     1013
# 3      Conv-V 2019-03-05 15:05:11.367  18998866608708     4     1013
# 4      Conv-V 2019-03-05 15:05:05.377  18998866607367     4     1013
# 5      Conv-V 2019-03-05 15:04:23.297  18998866610237     2      998
# 6      Conv-V 2019-03-05 15:04:17.277  18998866604953     2      998
# 7      Conv-V 2019-03-05 15:04:11.277  18998866608708     1      998
# 8      Conv-V 2019-03-05 15:04:05.767  18998866607367     2      998
# 9      Conv-V 2019-03-05 15:03:23.670  18998866610237     3      991
# 10     Conv-V 2019-03-05 15:03:17.670  18998866604953     3      991
# 11     Conv-V 2019-03-05 15:03:11.667  18998866608708     3      991
# 12     Conv-V 2019-03-05 15:03:05.597  18998866607367     7      991
# ...
